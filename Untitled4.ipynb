# %% [markdown]
# <a href="https://colab.research.google.com/github/AMSecretAgent/researchhproject/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 5, 100)
y = 5 * x + 7

plt.plot(x, y)
plt.title('Research Output Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
